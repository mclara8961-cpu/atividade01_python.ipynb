# %% [markdown]
# <a href="https://colab.research.google.com/github/mclara8961-cpu/atividade01_python.ipynb/blob/main/atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Atividade 01-Introdução ao Python
#Criando o primeiro código em python
print('Olá,mundo!')
print('Curso Técnico em Informática')

#Criando um programa com entrada de dados
disciplina = input('Digite o nome da disciplina:')
conteudo = input('Digite o conteúdo estudado:')
atividade = input('Digite o número da atividade:')
print('\n---Informações da Atividade---')
print('Disciplina:', disciplina)
print('Conteudo:', conteudo)
print('Aividade:', atividade)
# Out:
# Olá,mundo!
# Curso Técnico em Informática
# Digite o nome da disciplina:Algoritmos e lógica de programação
# Digite o conteúdo estudado:Python e GitHub
# Digite o número da atividade:01
#
# ---Informações da Atividade---
# Disciplina: Algoritmos e lógica de programação
# Conteudo: Python e GitHub
# Aividade: 01

# %%
numero1 = 10
numero2 = 20
soma = numero1+numero2
print(f'Resultado {soma}')
# Out:
# Resultado 30
